# %% [markdown]
# # Global mean time series
#
# This notebook shows how to use the global_time_series diagnostic. Here we focus on the Timeseries and the Gregory Plot functionalities.

# %% [markdown]
# The `Timeseries` class provides an easy interface to plot gloabl time series for a given list of experiments and a variable or formula.

# %%
from global_time_series import Timeseries

# %% [markdown]
# Let's plot the global mean temperature for the historical experiment, with a comparison done with the same ERA5 time span and 1990-1999 climatology.

# %%
ts = Timeseries(var='2t', models='IFS-NEMO', exps='historical-1990', sources='lra-r100-monthly',
                startdate='1990-01-01', enddate='1999-12-01',
                std_startdate='1990-01-01', std_enddate='1999-12-01', expand=False,
                loglevel='INFO')

# %% [markdown]
# By default the `Timeseries` class will use `ERA5` as the reference dataset, but you can change it by setting the `plot_ref_kw` parameter to the desired dataset.
#
# The timeseries is generated, plot and saved by running the `run` method of the `Timeseries` class.
# By default monthly and annual mean are evaluated, but you can change it by setting the parameter to `monthly=False` or `annual=False`.
# The reference data can be plotted by setting the `plot_ref=True` parameter.

# %%
ts.run()
# Out:
# 2024-05-17 21:00:48 :: Timeseries :: INFO     -> Retrieving data for IFS-NEMO historical-1990 lra-r100-monthly
# 2024-05-17 21:00:48 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:00:48 :: Reader :: INFO     -> No specific fix found, will call the default fix IFS-NEMO-default
# 2024-05-17 21:00:48 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-05-17 21:00:48 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly
# 2024-05-17 21:00:49 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-17 21:00:50 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-17 21:01:09 :: Timeseries :: INFO     -> Monthly data retrieved
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:01:09 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:01:09 :: Timeseries :: INFO     -> Annual data retrieved
# 2024-05-17 21:01:09 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-05-17 21:01:09 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-17 21:01:10 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-05-17 21:01:10 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-05-17 21:01:10 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-17 21:01:10 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:01:10 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:01:10 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:01:10 :: Timeseries :: INFO     -> Plotting the timeseries
# /home/b/b382397/.conda/envs/aqua/lib/python3.12/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# /home/b/b382397/.conda/envs/aqua/lib/python3.12/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# 2024-05-17 21:01:54 :: Timeseries :: INFO     -> Saving figure to pdf
# 2024-05-17 21:01:54 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2024-05-17 21:01:55 :: create_folder :: INFO     -> Folder ./netcdf already exists

# %% [markdown]
# Furthermore, the user can also combine time series and plot them against each other. The resulting "Gregory"-like plot allows the user to investigate the annual cycle as well as to detect model drift (if existing).

# %%
from global_time_series import GregoryPlot

# %% [markdown]
# Also in this case we have a simple class defined. The `GregoryPlot` class provides an easy interface to plot the Gregory-like plot for a given list of experiments.
#
# The comparison is done against ERA5 for the 2m temperature and CERES for the TOA net fluxes.
#
# By default both monthly and annual cycles are plotted, but the user can choose to plot only one of them by setting the `monthly` and `annual` parameters to `True` or `False`.

# %%
gp = GregoryPlot(models=['ICON','ICON'], exps=['historical-1990', 'ssp370'], sources=['lra-r100-monthly', 'lra-r100-monthly'],
            loglevel='INFO', monthly=False, annual=True)

# %%
gp.run()
# Out:
# 2024-05-17 21:02:06 :: Gregory plot :: INFO     -> Retrieving data for ICON historical-1990 lra-r100-monthly
# 2024-05-17 21:02:06 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:02:06 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-hist-lra
# 2024-05-17 21:02:06 :: Reader :: INFO     -> Fix names icon-destine-v1-hist-lra found in fixes files
# 2024-05-17 21:02:06 :: Reader :: INFO     -> Parent fix icon-destine-v1 found! Mergin with fixer_name fixes icon-destine-v1-hist-lra!
# 2024-05-17 21:02:06 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-17 21:02:06 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-05-17 21:02:30 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '1991-03-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '1991-03-01T00:00'}}
# 2024-05-17 21:02:30 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-05-17 21:02:30 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-05-17 21:02:30 :: Reader :: INFO     -> coordinates adjusted to ifs by AQUA fixer
# 2024-05-17 21:02:30 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:02:30 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:02:30 :: timmean_chunk_completeness :: INFO     -> 17 chunks from 1990-01-01 00:00:00 to 2006-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:02:30 :: timmean_chunk_completeness :: WARNING  -> Chunk 2006-01-31 00:00:00->2006-12-31 00:00:00 for has 5 elements instead of expected 12, timmean() will exclude this
# 2024-05-17 21:02:30 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:02:31 :: timmean_chunk_completeness :: INFO     -> 17 chunks from 1990-01-01 00:00:00 to 2006-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:02:31 :: timmean_chunk_completeness :: WARNING  -> Chunk 2006-01-31 00:00:00->2006-12-31 00:00:00 for has 5 elements instead of expected 12, timmean() will exclude this
# 2024-05-17 21:02:31 :: Gregory plot :: INFO     -> Retrieving data for ICON ssp370 lra-r100-monthly
# 2024-05-17 21:02:31 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-ssp370-lra
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Fix names icon-destine-v1-ssp370-lra found in fixes files
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Parent fix icon-destine-v1-ssp370 found! Mergin with fixer_name fixes icon-destine-v1-ssp370-lra!
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-17 21:02:31 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '2020-09-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '2020-09-01T00:00'}}
# 2024-05-17 21:02:51 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-05-17 21:02:51 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-05-17 21:02:51 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:02:51 :: timmean_chunk_completeness :: INFO     -> 11 chunks from 2020-01-01 00:00:00 to 2030-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:02:51 :: timmean_chunk_completeness :: WARNING  -> Chunk 2030-01-31 00:00:00->2030-12-31 00:00:00 for has 2 elements instead of expected 12, timmean() will exclude this
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:02:51 :: timmean_chunk_completeness :: INFO     -> 11 chunks from 2020-01-01 00:00:00 to 2030-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:02:51 :: timmean_chunk_completeness :: WARNING  -> Chunk 2030-01-31 00:00:00->2030-12-31 00:00:00 for has 2 elements instead of expected 12, timmean() will exclude this
# 2024-05-17 21:02:51 :: Gregory plot :: WARNING  -> No monthly data available. Monthly plot will not be drawn.
# 2024-05-17 21:02:51 :: Ref ts Gregory :: INFO     -> Reference data will be retrieved rom 1980-01-01 to 2010-12-31.
# 2024-05-17 21:02:51 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-05-17 21:02:51 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-05-17 21:02:51 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:02:51 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:02:51 :: timmean_chunk_completeness :: INFO     -> 31 chunks from 1980-01-01 00:00:00 to 2010-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:03:08 :: Ref toa Gregory :: INFO     -> Reference data will be retrieved rom 2001-01-01 to 2020-12-31.
# 2024-05-17 21:03:08 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi
# 2024-05-17 21:03:08 :: Reader :: INFO     -> Fix names in metadata is ceres-ebaf-destine-v1
# 2024-05-17 21:03:08 :: Reader :: INFO     -> Fix names ceres-ebaf-destine-v1 found in fixes files
# 2024-05-17 21:03:08 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-17 21:03:08 :: Reader :: INFO     -> Retrieving variables: ['mtnlwrf', 'mtnswrf']
# 2024-05-17 21:03:09 :: Reader :: INFO     -> Variables to be fixed: {'mtnlwrf': {'derived': '0.-toa_lw_all_mon', 'grib': True, 'attributes': {'valid_min': -500, 'valid_max': 0, 'positive': 'down'}}, 'mtnswrf': {'derived': 'solar_mon-toa_sw_all_mon', 'grib': True, 'attributes': {'valid_min': 0, 'valid_max': 1400, 'positive': 'down'}}}
# 2024-05-17 21:03:09 :: Reader :: INFO     -> mtnlwrf: converting units W m-2 --> W m**-2
# 2024-05-17 21:03:09 :: Reader :: INFO     -> mtnswrf: converting units W m-2 --> W m**-2
# 2024-05-17 21:03:09 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-17 21:03:09 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-17 21:03:09 :: timmean_chunk_completeness :: INFO     -> 20 chunks from 2001-01-01 00:00:00 to 2020-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-17 21:03:30 :: Gregory plot :: INFO     -> Saving figure to pdf
# 2024-05-17 21:03:30 :: create_folder :: INFO     -> Folder ./pdf already exists
# posx and posy should be finite values
# 2024-05-17 21:03:30 :: Gregory plot :: INFO     -> Saving data to netcdf
# 2024-05-17 21:03:30 :: create_folder :: INFO     -> Folder ./netcdf already exists
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
