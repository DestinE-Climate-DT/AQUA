# %% [markdown]
# ## Kolmogorov-Smirnov Test

# %% [markdown]
# ### Import modules

# %%
from replicability import ks_test

# %% [markdown]
# ### Creating request for the KS test

# %% [markdown]
# We need to create a dictionary containing the name of the two ensemles and directory of the Performance Indicies of those ensembles along with the output directory

# %%
request = {
    "ensemble1" : "Double Precision",
    "ensemble1_PI_dir" : "/pfs/lustrep3/scratch/project_465000454/kkeller/lab/replicability_mixed/PI_Scores/double_precision",
    
    "ensemble2" : "Mixed Precision",
    "ensemble2_PI_dir" : "/pfs/lustrep3/scratch/project_465000454/kkeller/lab/replicability_mixed/PI_Scores/mixed_precision",
    
    "members" : ["fc1", "fc2", "fc3", "fc4", "fc5", "fc6", "fc8", "fc10"],
    "outputdir" : "./output"
}

# %% [markdown]
# ### Function

# %%
ks_test_diag = ks_test(request)
ks_test_diag.plot()
# Out:
# 2024-02-20 20:08:14 :: km_test_score_df :: INFO     -> Generating Kolmogorov test results
# 2024-02-20 20:08:14 :: create_folder :: INFO     -> Plotting Kolmogorov test results!
# /pfs/lustrep3/scratch/project_465000454/sughosh/AQUA/diagnostics/replicability/replicability/ks_test.py:218: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.add_patch(plt.Rectangle((j, i), 0.9, 0.9, fill=True, color=color, edgecolor='white'))
