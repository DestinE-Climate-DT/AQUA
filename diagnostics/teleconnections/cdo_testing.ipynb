# %% [markdown]
# # CDO testing
#
# This notebook runs the teleconnection diagnostics written with cdo python bindings

# %%
import cdo
from cdotesting import *
from tools import *

# Teleconnection config details
diagname  = 'teleconnections'
machine   = 'wilma'

# Opening yml files
config   = load_config(machine)
namelist = load_namelist(diagname)

# %% [markdown]
# ## NAO

# %%
# Configuration specific to the NAO teleconnection
telecname = 'NAO'
fieldname = namelist[telecname]['field']
infile = config[diagname][telecname]['input']

test = station_based_cdo(infile,namelist,telecname)
test[config[diagname][telecname]['var']].plot()

# %%
# Configuration specific to the ENSO teleconnection
telecname = 'ENSO'
fieldname = namelist[telecname]['field']
infile = config[diagname][telecname]['input']

test = regional_mean_cdo(infile,namelist,telecname)
test[config[diagname][telecname]['var']].plot()
