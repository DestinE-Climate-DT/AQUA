# %%
import cftime
import dask
import datetime
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
from index import *
from plots import *
from tools import *

sys.path.insert(1, '/work/bb1153/b382289/AQUA/')
from aqua import Reader

# %%
machine   = 'wilma'
diagname  = 'teleconnections'
telecname = 'NAO'

config   = load_config(machine)
namelist = load_namelist(diagname)

# %% [markdown]
# ## Retrieve data

# %%
configdir = '/work/bb1153/b382289/AQUA/config'
reader = Reader(model='IFS', exp='tco2559-ng5', source='ICMGG_atm2d',
                freq='mon',regrid='r100',configdir=configdir)

# %%
data = reader.retrieve(fix=False)

# %%
infile = data['msl']
print(infile.dims)
print(infile.coords)
# Out:
# ('time', 'value')
# Coordinates:
#     lat      (value) float64 dask.array<chunksize=(26306560,), meta=np.ndarray>
#     lon      (value) float64 dask.array<chunksize=(26306560,), meta=np.ndarray>
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-20T01:00:00 ... 2021-01-01

# %% [markdown]
# ## Coordinates selection

# %%
infile.isel(value=40)
# Out:
# <xarray.DataArray 'msl' (time: 8329)>
# dask.array<getitem, shape=(8329,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     lat      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon      float64 dask.array<chunksize=(), meta=np.ndarray>
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-20T01:00:00 ... 2021-01-01
# Attributes: (12/16)
#     paramId:                    151
#     dataType:                   fc
#     numberOfPoints:             26306560
#     typeOfLevel:                surface
#     stepUnits:                  1
#     stepType:                   instant
#     ...                         ...
#     cfName:                     air_pressure_at_mean_sea_level
#     cfVarName:                  msl
#     missingValue:               9999
#     totalNumber:                0
#     NV:                         0
#     gridDefinitionDescription:  Gaussian Latitude/Longitude Grid

# %%
infile.value.lon[45].values
# Out:
# array(12.85714286)

# %%
test = infile.value.lon
test.sel(infile.value['lon']=0)
# Out:
#   Cell In[42], line 2
#     test.sel(infile.value['lon']:0)
#                                 ^
# SyntaxError: invalid syntax

# %%
lon1 = lon_180_to_360(namelist[telecname]['lon1'])
lon1 = namelist[telecname]['lon1']
lat1 = namelist[telecname]['lat1']
lon2 = lon_180_to_360(namelist[telecname]['lon2'])
lat2 = namelist[telecname]['lat2']

# %%
infile.sel(lat=lat1,lon=lon1,method='nearest')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 infile.sel(lat=lat1,lon=lon1,method='nearest')
#
# File /work/bb1153/b382289/mambaforge/envs/teleconnections/lib/python3.10/site-packages/xarray/core/dataarray.py:1524, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1414 def sel(
#    1415     self: T_DataArray,
#    1416     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1420     **indexers_kwargs: Any,
#    1421 ) -> T_DataArray:
#    1422     """Return a new DataArray whose data is given by selecting index
#    1423     labels along the specified dimension(s).
#    1424
#    (...)
#    1522     Dimensions without coordinates: points
#    1523     """
# -> 1524     ds = self._to_temp_dataset().sel(
#    1525         indexers=indexers,
#    1526         drop=drop,
#    1527         method=method,
# ...

# %%
test
# Out:
# <xarray.DataArray 'lat' ()>
# dask.array<getitem, shape=(), dtype=float64, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     lat      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon      float64 dask.array<chunksize=(), meta=np.ndarray>
# Attributes:
#     long_name:      latitude
#     units:          degrees_north
#     standard_name:  latitude

# %%
lon1 = lon_180_to_360(namelist[telecname]['lon1'])
lon1 = namelist[telecname]['lon1']
lat1 = namelist[telecname]['lat1']
lon2 = lon_180_to_360(namelist[telecname]['lon2'])
lat2 = namelist[telecname]['lat2']

# %%
#infile = reader.regrid(infile)
#infile.sel(lon=lon1,lat=lat1,method='nearest')

# %%
infile
# Out:
# <xarray.DataArray 'msl' (time: 8329, value: 26306560)>
# dask.array<_set_fill_value, shape=(8329, 26306560), dtype=float64, chunksize=(1, 26306560), chunktype=numpy.ndarray>
# Coordinates:
#     lat      (value) float64 dask.array<chunksize=(26306560,), meta=np.ndarray>
#     lon      (value) float64 dask.array<chunksize=(26306560,), meta=np.ndarray>
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-20T01:00:00 ... 2021-01-01
# Dimensions without coordinates: value
# Attributes: (12/16)
#     paramId:                    151
#     dataType:                   fc
#     numberOfPoints:             26306560
#     typeOfLevel:                surface
#     stepUnits:                  1
#     stepType:                   instant
#     ...                         ...
#     cfName:                     air_pressure_at_mean_sea_level
#     cfVarName:                  msl
#     missingValue:               9999
#     totalNumber:                0
#     NV:                         0
# ...

# %%
coords.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 coords.index
#
# File /work/bb1153/b382289/mambaforge/envs/teleconnections/lib/python3.10/site-packages/xarray/core/common.py:268, in AttrAccessMixin.__getattr__(self, name)
#     266         with suppress(KeyError):
#     267             return source[name]
# --> 268 raise AttributeError(
#     269     f"{type(self).__name__!r} object has no attribute {name!r}"
#     270 )
#
# AttributeError: 'DataArray' object has no attribute 'index'

# %%
lon1 = lon_180_to_360(namelist[telecname]['lon1'])
lon1 = namelist[telecname]['lon1']
lat1 = namelist[telecname]['lat1']
lon2 = lon_180_to_360(namelist[telecname]['lon2'])
lat2 = namelist[telecname]['lat2']

# %%
data1 = infile.sel(lon=lon1,lat=lat1,method='nearest')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data1 = infile.sel(lon=lon1,lat=lat1,method='nearest')
#
# File /work/bb1153/b382289/mambaforge/envs/teleconnections/lib/python3.10/site-packages/xarray/core/dataarray.py:1524, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1414 def sel(
#    1415     self: T_DataArray,
#    1416     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1420     **indexers_kwargs: Any,
#    1421 ) -> T_DataArray:
#    1422     """Return a new DataArray whose data is given by selecting index
#    1423     labels along the specified dimension(s).
#    1424
#    (...)
#    1522     Dimensions without coordinates: points
#    1523     """
# -> 1524     ds = self._to_temp_dataset().sel(
#    1525         indexers=indexers,
#    1526         drop=drop,
# ...
