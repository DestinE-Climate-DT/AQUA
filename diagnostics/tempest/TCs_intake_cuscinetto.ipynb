# %% [markdown]
# # Tempest Extreme experiment with NextGEMS data
#
# This is trying to work with the intake catalog and using the regridder. Open the catalog and check that everything works correctly. Import functions we created ad-hoc for TCs

# %%
import sys
sys.path.append('../../')
import os
from datetime import datetime, timedelta
from glob import glob

from functionsTCs import *

from aqua.reader import catalogue
catalogue(catalog_file='../../config/catalog.yaml');
# Out:
# IFS	tco3999-ng5	2.8km experiment, coupled with FESOM
# 	- ICMGG_atm2d
# 	- ICMU_atm2d
# 	- ICMU_atm3d
# 	- interpolated_global
# 	- interpolated_np
# 	- interpolated_sp
# 	- interpolated_sp_ci
# IFS	tco2559-ng5	4km experiment, coupled with FESOM
# 	- ICMGG_atm2d
# 	- ICMU_atm2d
# 	- ICMU_atm3d
# 	- interpolated_global
# 	- interpolated_np
# 	- interpolated_sp
# IFS	tco1279-orca025	9km baseline, coupled to NEMO, deep conv ON
# 	- ICMGG_atm2d
# 	- ICMU_atm2d
# 	- ICMU_atm3d
#
# FESOM	tco3999-ng5	2.5km experiment, coupuled with IFS
# 	- elem_grid
# 	- node_grid
# 	- np	nearest-neighbor interpolation to lat-lon grid
# 	- interpolated_global2d
# 	- interpolated_global_TS
# 	- interpolated_global_UV
# 	- interpolated_np
# 	- interpolated_sp
# 	- original_2d	original 2d output
# 	- original_3d	original 3d output
# FESOM	tco2559-ng5	5km experiment, coupuled with IFS
# 	- elem_grid
# 	- node_grid
# 	- interpolated_global2d
# 	- interpolated_global_TS
# 	- interpolated_global_UV
# 	- interpolated_np
# 	- interpolated_sp
# 	- original_2d	original 2d output
# 	- original_3d	original 3d output
#
# ICON	ngc2009	5km coupled run, main ICON nextGEMS C2 run
# 	- atm_2d_ml
# 	- atm_2d_ml_R02B09
# 	- atm_2d_ml_R02B08
# 	- atm_2d_ml_R02B06
# 	- oce_200m_atmgrid
# 	- oce_200m_atmgrid_R02B09
# ICON	hpx	Some Healpix data
# 	- result
# ICON	grids	ICON grids
#
# MSWEP	past	past MSWEP v280 data
# 	- monthly	monthly MSWEP_V280 data
# 	- daily	daily MSWEP_V280 data
# 	- 3hourly	3 hourly MSWEP_V280 data

# %% [markdown]
# Load the data from the intake catalog - regridding to a regular grid for data to be tracked (r100) and for high-resolution (r010, since we cannot easily work with gaussian reduced) and the apply the detection from TempestExtremes in order to filter the high resolution data with the regions in the surroundings of the cyclone

# %%
# path to input directory
regdir='/home/b/b382216/scratch/regrid_intake'
tmpdir='/home/b/b382216/scratch/tmpdir_intake'
fulldir='/home/b/b382216/scratch/fullres'

# dimension of the box to be saved
boxdim=10

# resolution for high and low data
lowgrid='r100'
highgrid='r100'

# variables to be stored
varlist = ['psl', 'uas', 'vas', 'pr']
#varlist = ['pr']

# dicitonary with the original filenames
original_dictionary = {'psl': 'msl', 'uas': '10u', 'vas': '10v', 'pr': 'tp'}

# ndays to be saved
ndays = 90

#initial year and month
init_year=2020
init_month=7
init_day=1

# timestep to run on
t1=0
t2=6*4*ndays

# initial date from which start detection/tracking
initial_date=datetime(init_year, init_month, init_day, 0, 0, 0)

# loop on timerecords
for t in range(t1, t2, 6): 

    tttt = initial_date + timedelta(hours=t)
    tstep = tttt.strftime('%Y%m%dT%H')
    print(tstep)
    # read from catalog, interpolate, write to disk and create a dictionary with useful information
    tempest_dictionary = readwrite_from_intake(model='IFS', exp = 'tco2559-ng5', timestep=tttt, grid=lowgrid, tgtdir=regdir)

    # define the tempest detect nodes output
    txt_file = os.path.join(tmpdir, 'tempest_output_' + tstep + '.txt')

    # run the node detection on the low res files
    tempest_command = run_detect_nodes(tempest_dictionary, tempest_dictionary['regrid_file'], txt_file)

    # remove the low res files
    clean_files([tempest_dictionary['regrid_file']])

    # identify the nodes
    tempest_nodes = read_lonlat_nodes(txt_file)

    # load the highres files
    #reader2d = Reader(model='IFS', exp = 'tco2559-ng5', source="ICMGG_atm2d")
    reader2d = Reader(model='IFS', exp = 'tco2559-ng5', source="ICMGG_atm2d", regrid=highgrid)
    fulldata = reader2d.retrieve().sel(time=tstep)
    
    # loop on variables to write to disk only the subset of high res files
    for var in varlist : 

        varfile = original_dictionary[var]

        data = reader2d.regrid(fulldata[varfile])
        data.name = var
        xfield = store_fullres_field(0, data, tempest_nodes, boxdim)

        store_file = os.path.join(tmpdir, f'TC_{var}_{tstep}.nc')
        write_fullres_field(xfield, store_file)
# Out:
# 20200701T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200701T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-01 00:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 1108
# ....Rejected (contour msl): 156
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 34
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200701T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200701T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-01 06:00:00
# ....Total candidates: 3
# ....Rejected (  location): 0
# ....Rejected (    merged): 1116
# ....Rejected (contour msl): 167
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 37
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200701T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200701T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-01 12:00:00
# ....Total candidates: 7
# ....Rejected (  location): 0
# ....Rejected (    merged): 1105
# ....Rejected (contour msl): 160
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 42
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200701T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200701T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-01 18:00:00
# ....Total candidates: 3
# ....Rejected (  location): 0
# ....Rejected (    merged): 1118
# ....Rejected (contour msl): 156
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 42
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200702T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200702T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-02 00:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 1145
# ....Rejected (contour msl): 141
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 39
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200702T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200702T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-02 06:00:00
# ....Total candidates: 6
# ....Rejected (  location): 0
# ....Rejected (    merged): 1154
# ....Rejected (contour msl): 154
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 37
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200702T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200702T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-02 12:00:00
# ....Total candidates: 8
# ....Rejected (  location): 0
# ....Rejected (    merged): 1115
# ....Rejected (contour msl): 146
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 38
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200702T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200702T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-02 18:00:00
# ....Total candidates: 9
# ....Rejected (  location): 0
# ....Rejected (    merged): 1179
# ....Rejected (contour msl): 137
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 32
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200703T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200703T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-03 00:00:00
# ....Total candidates: 11
# ....Rejected (  location): 0
# ....Rejected (    merged): 1120
# ....Rejected (contour msl): 139
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 31
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200703T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200703T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-03 06:00:00
# ....Total candidates: 12
# ....Rejected (  location): 0
# ....Rejected (    merged): 1107
# ....Rejected (contour msl): 143
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 29
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200703T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200703T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-03 12:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1139
# ....Rejected (contour msl): 148
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 37
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200703T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200703T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-03 18:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 1135
# ....Rejected (contour msl): 142
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 39
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200704T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200704T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-04 00:00:00
# ....Total candidates: 6
# ....Rejected (  location): 0
# ....Rejected (    merged): 1080
# ....Rejected (contour msl): 142
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 38
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200704T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200704T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-04 06:00:00
# ....Total candidates: 6
# ....Rejected (  location): 0
# ....Rejected (    merged): 1147
# ....Rejected (contour msl): 148
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 32
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200704T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200704T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-04 12:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 1122
# ....Rejected (contour msl): 144
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 38
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200704T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200704T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-04 18:00:00
# ....Total candidates: 2
# ....Rejected (  location): 0
# ....Rejected (    merged): 1182
# ....Rejected (contour msl): 141
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 35
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200705T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200705T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-05 00:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1053
# ....Rejected (contour msl): 154
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 27
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200705T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200705T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-05 06:00:00
# ....Total candidates: 8
# ....Rejected (  location): 0
# ....Rejected (    merged): 1093
# ....Rejected (contour msl): 145
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 25
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200705T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200705T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-05 12:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1099
# ....Rejected (contour msl): 152
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 30
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200705T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200705T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-05 18:00:00
# ....Total candidates: 7
# ....Rejected (  location): 0
# ....Rejected (    merged): 1108
# ....Rejected (contour msl): 132
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 31
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200706T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200706T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-06 00:00:00
# ....Total candidates: 3
# ....Rejected (  location): 0
# ....Rejected (    merged): 1084
# ....Rejected (contour msl): 133
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 32
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200706T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200706T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-06 06:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1052
# ....Rejected (contour msl): 157
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 29
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200706T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200706T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-07-06 12:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1168
# ....Rejected (contour msl): 138
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 37
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200706T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200706T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
# ...
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-27 00:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 984
# ....Rejected (contour msl): 127
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 24
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200927T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200927T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200927T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-27 06:00:00
# ....Total candidates: 2
# ....Rejected (  location): 0
# ....Rejected (    merged): 987
# ....Rejected (contour msl): 161
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 24
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200927T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200927T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200927T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-27 12:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 1039
# ....Rejected (contour msl): 140
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 29
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200927T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200927T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200927T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-27 18:00:00
# ....Total candidates: 4
# ....Rejected (  location): 0
# ....Rejected (    merged): 978
# ....Rejected (contour msl): 140
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 25
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200928T00
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200928T00.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200928T00.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-28 00:00:00
# ....Total candidates: 7
# ....Rejected (  location): 0
# ....Rejected (    merged): 990
# ....Rejected (contour msl): 127
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 23
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200928T06
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200928T06.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200928T06.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-28 06:00:00
# ....Total candidates: 9
# ....Rejected (  location): 0
# ....Rejected (    merged): 958
# ....Rejected (contour msl): 148
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 22
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200928T12
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200928T12.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200928T12.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-28 12:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 970
# ....Rejected (contour msl): 141
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 23
# ....Done
# ..Done
# ------------------------------------------------------------
# 20200928T18
# Arguments:
#   --in_data <string> ["/home/b/b382216/scratch/regrid_intake/regrid_20200928T18.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> [""]
#   --diag_connect <bool> [false]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200928T18.txt"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["msl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --closedcontourcmd <string> ["msl,200.0,5.5,0;_DIFF(z(30000Pa),z(50000Pa)),-58.8,6.5,1.0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["msl,min,0;_VECMAG(u10m,v10m),max,2"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> ["6hr"]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..msl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# .._DIFF(z(30000Pa),z(50000Pa)) decreases by 58.800000 over 6.500000 degrees (max search 1.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of msl within 0.000000 degrees
# ..Maximum of _VECMAG(u10m,v10m) within 2.000000 degrees
# ..Done
# Begin search operation
# ..Generating RLL grid data
# ....Total calculated grid area: 1.256637061435737e+01 sr
# ....Done
# ..Time 2020-09-28 18:00:00
# ....Total candidates: 5
# ....Rejected (  location): 0
# ....Rejected (    merged): 989
# ....Rejected (contour msl): 130
# ....Rejected (contour _DIFF(z(30000Pa),z(50000Pa))): 25
# ....Done
# ..Done
# ------------------------------------------------------------

# %% [markdown]
# Put together all the tracks from the detect nodes and run the stich nodes to define the final tracks

# %%
#now run stitch nodes only every month

import pandas as pd
tmpdir='/home/b/b382216/scratch/tmpdir_intake'

# initial year and month
init_year=2020
init_month=7

# final year and month
end_year=2020
end_month=9

yrmonths = pd.period_range(start=(str(init_year)+str(init_month).zfill(2)),end=(str(end_year)+str(end_month).zfill(2)), freq='M').strftime('%Y%m')
print (yrmonths)

for yrm in yrmonths:
    # output from detect nodes
    filenames = sorted(glob(os.path.join(tmpdir,f'tempest_output_{yrm}*')))
    print (filenames)
    # create output file with output from stitch nodes 
    track_file = os.path.join(tmpdir, f'tempest_track_{yrm}.txt')

    # run stitch nodes, MAXGAP set to 6h to match the input files res
    stitch_string = run_stitch_nodes(filenames, track_file, maxgap = '6h')
# Out:
# Index(['202007', '202008', '202009'], dtype='object')
# ['/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200701T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200702T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200703T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200704T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200705T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200706T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200707T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200707T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200707T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200707T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200708T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200708T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200708T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200708T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200709T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200709T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200709T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200709T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200710T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200710T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200710T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200710T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200711T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200711T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200711T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200711T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200712T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200712T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200712T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200712T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200713T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200713T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200713T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200713T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200714T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200714T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200714T12.txt', '/home/b/b382216/scratch/tmpdir_intake/ ...
# Arguments:
#   --in <string> ["full_nodes.txt"]
#   --in_list <string> [""]
#   --in_connect <string> [""]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_track_202007.txt"]
#   --in_fmt <string> ["lon,lat,slp,wind"]
#   --range <double> [8.000000] (degrees)
#   --mintime <string> ["54h"]
#   --time_begin <string> [""]
#   --time_end <string> [""]
#   --min_endpoint_dist <double> [0.000000] (degrees)
#   --min_path_dist <double> [0.000000] (degrees)
#   --maxgap <string> ["6h"]
#   --threshold <string> ["wind,>=,10.0,10;lat,<=,50.0,10;lat,>=,-50.0,10"] [col,op,value,count;...]
#   --caltype <string> ["standard"] (none|standard|noleap|360_day)
#   --allow_repeated_times <bool> [false]
#   --out_file_format <string> ["gfdl"] (gfdl|csv|csvnohead)
# ------------------------------------------------------------
# Parsing thresholds
# ..wind greater than or equal to 10.000000 at least 10 time(s)
# ..lat less than or equal to 50.000000 at least 10 time(s)
# ..lat greater than or equal to -50.000000 at least 10 time(s)
# ..Done
# Loading candidate data
# ..Discrete times: 124 (2020-07-01 00:00:00 to 2020-07-31 18:00:00)
# ..Done
# Creating KD trees at each time level.. Done
# Populating set of path segments.. Done
# Constructing paths
# ..Paths rejected (mintime): 96
# ..Paths rejected (minendpointdist): 0
# ..Paths rejected (minpathdist): 0
# ..Paths rejected (threshold): 2
# ..Total paths found: 1
# ..Done
# Writing results.. Done
# Cleanup.. Done
# ------------------------------------------------------------
# ['/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200801T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200801T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200801T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200801T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200802T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200802T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200802T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200802T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200803T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200803T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200803T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200803T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200804T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200804T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200804T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200804T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200805T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200805T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200805T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200805T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200806T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200806T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200806T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200806T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200807T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200807T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200807T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200807T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200808T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200808T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200808T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200808T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200809T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200809T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200809T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200809T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200810T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200810T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200810T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200810T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200811T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200811T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200811T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200811T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200812T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200812T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200812T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200812T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200813T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200813T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200813T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200813T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200814T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200814T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200814T12.txt', '/home/b/b382216/scratch/tmpdir_intake/ ...
# Arguments:
#   --in <string> ["full_nodes.txt"]
#   --in_list <string> [""]
#   --in_connect <string> [""]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_track_202008.txt"]
#   --in_fmt <string> ["lon,lat,slp,wind"]
#   --range <double> [8.000000] (degrees)
#   --mintime <string> ["54h"]
#   --time_begin <string> [""]
#   --time_end <string> [""]
#   --min_endpoint_dist <double> [0.000000] (degrees)
#   --min_path_dist <double> [0.000000] (degrees)
#   --maxgap <string> ["6h"]
#   --threshold <string> ["wind,>=,10.0,10;lat,<=,50.0,10;lat,>=,-50.0,10"] [col,op,value,count;...]
#   --caltype <string> ["standard"] (none|standard|noleap|360_day)
#   --allow_repeated_times <bool> [false]
#   --out_file_format <string> ["gfdl"] (gfdl|csv|csvnohead)
# ------------------------------------------------------------
# Parsing thresholds
# ..wind greater than or equal to 10.000000 at least 10 time(s)
# ..lat less than or equal to 50.000000 at least 10 time(s)
# ..lat greater than or equal to -50.000000 at least 10 time(s)
# ..Done
# Loading candidate data
# ..Discrete times: 124 (2020-08-01 00:00:00 to 2020-08-31 18:00:00)
# ..Done
# Creating KD trees at each time level.. Done
# Populating set of path segments.. Done
# Constructing paths
# ..Paths rejected (mintime): 78
# ..Paths rejected (minendpointdist): 0
# ..Paths rejected (minpathdist): 0
# ..Paths rejected (threshold): 1
# ..Total paths found: 6
# ..Done
# Writing results.. Done
# Cleanup.. Done
# ------------------------------------------------------------
# ['/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200901T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200901T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200901T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200901T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200902T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200902T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200902T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200902T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200903T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200903T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200903T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200903T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200904T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200904T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200904T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200904T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200905T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200905T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200905T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200905T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200906T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200906T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200906T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200906T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200907T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200907T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200907T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200907T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200908T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200908T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200908T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200908T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200909T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200909T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200909T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200909T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200910T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200910T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200910T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200910T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200911T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200911T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200911T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200911T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200912T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200912T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200912T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200912T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200913T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200913T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200913T12.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200913T18.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200914T00.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200914T06.txt', '/home/b/b382216/scratch/tmpdir_intake/tempest_output_20200914T12.txt', '/home/b/b382216/scratch/tmpdir_intake/ ...
# Arguments:
#   --in <string> ["full_nodes.txt"]
#   --in_list <string> [""]
#   --in_connect <string> [""]
#   --out <string> ["/home/b/b382216/scratch/tmpdir_intake/tempest_track_202009.txt"]
#   --in_fmt <string> ["lon,lat,slp,wind"]
#   --range <double> [8.000000] (degrees)
#   --mintime <string> ["54h"]
#   --time_begin <string> [""]
#   --time_end <string> [""]
#   --min_endpoint_dist <double> [0.000000] (degrees)
#   --min_path_dist <double> [0.000000] (degrees)
#   --maxgap <string> ["6h"]
#   --threshold <string> ["wind,>=,10.0,10;lat,<=,50.0,10;lat,>=,-50.0,10"] [col,op,value,count;...]
#   --caltype <string> ["standard"] (none|standard|noleap|360_day)
#   --allow_repeated_times <bool> [false]
#   --out_file_format <string> ["gfdl"] (gfdl|csv|csvnohead)
# ------------------------------------------------------------
# Parsing thresholds
# ..wind greater than or equal to 10.000000 at least 10 time(s)
# ..lat less than or equal to 50.000000 at least 10 time(s)
# ..lat greater than or equal to -50.000000 at least 10 time(s)
# ..Done
# Loading candidate data
# ..Discrete times: 112 (2020-09-01 00:00:00 to 2020-09-28 18:00:00)
# ..Done
# Creating KD trees at each time level.. Done
# Populating set of path segments.. Done
# Constructing paths
# ..Paths rejected (mintime): 85
# ..Paths rejected (minendpointdist): 0
# ..Paths rejected (minpathdist): 0
# ..Paths rejected (threshold): 0
# ..Total paths found: 6
# ..Done
# Writing results.. Done
# Cleanup.. Done
# ------------------------------------------------------------

# %% [markdown]
# Version with +- n days buffer

# %%
import pandas as pd
import os
import glob

tmpdir = '/home/b/b382216/scratch/tmpdir_intake'

# initial year, month, and day
init_year = 2020
init_month = 7
init_day = 1

# final year, month, and day
end_year = 2020
end_month = 9
end_day = 30

#number of days in which each month is extended at the beginning and at the end
n_days_ext = 10

for month in pd.date_range(start=f'{init_year}-{init_month}', end=f'{end_year}-{end_month}', freq='M').strftime('%m'):
    if month == "02":
        end_day=28
        # create DatetimeIndex with daily frequency
        dates = pd.date_range(start=f'{init_year}-{month}-{init_day}', end=f'{end_year}-{month}-{end_day}', freq='D')
        # get indexes of yrm and 10 days before and after
        yrm_index = dates[dates.year == init_year][dates.month == month].strftime('%Y%m%d')
        before_index = dates[dates.year == init_year][dates.month == month].shift(-n_days_ext, freq='D').strftime('%Y%m%d')
        after_index = dates[dates.year == end_year][dates.month == month].shift(n_days_ext, freq='D').strftime('%Y%m%d')

        # concatenate the indexes to create a single index
        date_index = before_index.append(yrm_index).append(after_index)

        # create list of file paths to include in glob pattern
        file_paths = [os.path.join(tmpdir, f'tempest_output_{date}*') for date in date_index]

        # use glob to get list of filenames that match the pattern
        filenames = []
        for file_path in file_paths:
            filenames.extend(glob.glob(file_path))
        print(filenames)

    else:
        # create DatetimeIndex with daily frequency
        dates = pd.date_range(start=f'{init_year}-{month}-{init_day}', end=f'{end_year}-{month}-{end_day}', freq='D')
        # get indexes of yrm and 10 days before and after
        yrm_index = dates[dates.year == init_year][dates.month == month].strftime('%Y%m%d')
        before_index = dates[dates.year == init_year][dates.month == month].shift(-n_days_ext, freq='D').strftime('%Y%m%d')
        after_index = dates[dates.year == end_year][dates.month == month].shift(n_days_ext, freq='D').strftime('%Y%m%d')

        # concatenate the indexes to create a single index
        date_index = before_index.append(yrm_index).append(after_index)
        # create list of file paths to include in glob pattern
        file_paths = [os.path.join(tmpdir, f'tempest_output_{date}*') for date in date_index]
        # use glob to get list of filenames that match the pattern
        filenames = []
        for file_path in file_paths:
            filenames.extend(glob.glob(file_path))
        print(filenames)
# Out:
# 07
# []
# 08
# []

# %% [markdown]
# Load the full res field and apply further cleanign according to the stich nodes

# %%
# variables to be stored
varlist = ['psl', 'uas', 'vas', 'pr']
boxdim = 10

for yrm in yrmonths:
    # create output file with output from stitch nodes 
    track_file = os.path.join(tmpdir, f'tempest_track_{yrm}.txt')
    # reordered_tracks is a dict containing the concatenated (in time) tracks
    # at eatch time step are associated all lons/lats

    reordered_tracks = reorder_tracks(track_file)

    # initialise full_res fields at 0 before the loop

    for var in varlist : 
        print(var)

        xfield = 0
        for idx in reordered_tracks.keys():

            timestep = datetime.strptime(idx, '%Y%m%d%H').strftime('%Y%m%dT%H')
            
            fullres_file = os.path.join(tmpdir, f'TC_{var}_{timestep}.nc')
            fullres_field = xr.open_mfdataset(fullres_file)[var]

            # get the full res field and store the required values around the Nodes
            xfield = store_fullres_field(xfield, fullres_field, reordered_tracks[idx], boxdim)

        print('Storing output')

        # store the file
        store_file = os.path.join(tmpdir, f'tempest_tracks_{var}_{yrm}.nc')
        write_fullres_field(xfield, store_file)
# Out:
# psl
# Storing output
# uas
# Storing output
# vas
# Storing output
# pr
# Storing output
# psl
# Storing output
# uas
# Storing output
# vas
# Storing output
# pr
# Storing output
# psl
# Storing output
# uas
# Storing output
# vas
# Storing output
# pr
# Storing output
# IOStream.flush timed out
