# %%
import sys
from aqua import Reader
# Out:
# FDB5 binary library not present on system, disabling FDB support.

# %%
reader = Reader(model="ICON", exp="test-healpix", source="healpix_0")
icon = reader.retrieve()

# %%
icon
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 2, level_full: 90, x: 12)
# Coordinates:
#   * time        (time) datetime64[ns] 2020-01-21 2020-01-22
#   * level_full  (level_full) int32 1 2 3 4 5 6 7 8 9 ... 83 84 85 86 87 88 89 90
# Dimensions without coordinates: x
# Data variables:
#     crs         float32 ...
#     t           (time, level_full, x) float32 dask.array<chunksize=(1, 90, 12), meta=np.ndarray>
#     2t          (time, x) float32 dask.array<chunksize=(1, 12), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.2.2 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Tue May 23 16:53:55 2023: cdo -f nc4 -select,name=tas,ta,ti...
#     CDO:          Climate Data Operators version 2.2.1 (https://mpimet.mpg.de...
