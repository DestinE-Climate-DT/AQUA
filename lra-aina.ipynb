# %%
from aqua import Reader

# %%
reader = Reader(model='IFS', exp='control-1990-nemo-dev', source='lra-r100-monthly')

# %%
data = reader.retrieve()
data
# Out:
# 2023-12-01 16:54:09 :: eccodes :: WARNING  -> ShortName tprate have multiple grib codes associated: ['260048', '172228']
# 2023-12-01 16:54:09 :: eccodes :: WARNING  -> AQUA will take the first so that tprate -> 260048, please set up a correct fix if this does not look right
# <xarray.Dataset>
# Dimensions:  (time: 3, lat: 180, lon: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 1990-01-01 1990-02-01 1990-03-01
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.0 1.0 2.0 3.0 4.0 ... 355.0 356.0 357.0 358.0 359.0
# Data variables:
#     2t       (time, lat, lon) float64 dask.array<chunksize=(3, 180, 360), meta=np.ndarray>
#     erate    (time, lat, lon) float64 dask.array<chunksize=(1, 180, 360), meta=np.ndarray>
#     msntrf   (time, lat, lon) float64 dask.array<chunksize=(1, 180, 360), meta=np.ndarray>
#     msshfl   (time, lat, lon) float64 dask.array<chunksize=(1, 180, 360), meta=np.ndarray>
# ...

# %%
from aqua import plot_single_map

# %%
plot_single_map(data.tprate.isel(time=0))
