# %% [markdown]
# # Global mean time series
#
# This notebook shows how to use the global_time_series diagnostic. Here we focus on the Timeseries and the Gregory Plot functionalities.

# %% [markdown]
# The `Timeseries` class provides an easy interface to plot gloabl time series for a given list of experiments and a variable or formula.

# %%
from global_time_series import Timeseries

# %% [markdown]
# Let's plot the global mean temperature for the historical experiment, with a comparison done with the same ERA5 time span and 1990-1999 climatology.

# %%
ts = Timeseries(var='2t', models='IFS-NEMO', exps='historical-1990', sources='lra-r100-monthly',
                startdate='1990-01-01', enddate='1999-12-01',
                std_startdate='1990-01-01', std_enddate='1999-12-01', expand=False,
                loglevel='INFO')

# %% [markdown]
# By default the `Timeseries` class will use `ERA5` as the reference dataset, but you can change it by setting the `plot_ref_kw` parameter to the desired dataset.
#
# The timeseries is generated, plot and saved by running the `run` method of the `Timeseries` class.
# By default monthly and annual mean are evaluated, but you can change it by setting the parameter to `monthly=False` or `annual=False`.
# The reference data can be plotted by setting the `plot_ref=True` parameter.

# %%
ts.run()
# Out:
# 2024-05-21 00:18:19 :: Timeseries :: INFO     -> Retrieving data for IFS-NEMO historical-1990 lra-r100-monthly
# 2024-05-21 00:18:20 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:18:20 :: Reader :: INFO     -> No specific fix found, will call the default fix IFS-NEMO-default
# 2024-05-21 00:18:20 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-05-21 00:18:20 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly
# 2024-05-21 00:18:20 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-21 00:18:21 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-21 00:18:30 :: Timeseries :: INFO     -> Monthly data retrieved
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:18:30 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:18:30 :: Timeseries :: INFO     -> Annual data retrieved
# 2024-05-21 00:18:30 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-05-21 00:18:30 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-21 00:18:31 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-05-21 00:18:31 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-05-21 00:18:31 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-21 00:18:31 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:18:31 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:18:31 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:18:31 :: Timeseries :: INFO     -> Plotting the timeseries
# /LUMI_TYKKY_Q52EApc/miniconda/envs/env1/lib/python3.12/site-packages/xarray/core/indexing.py:1617: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# /LUMI_TYKKY_Q52EApc/miniconda/envs/env1/lib/python3.12/site-packages/xarray/core/indexing.py:1617: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# 2024-05-21 00:21:03 :: Timeseries :: INFO     -> Saving figure to pdf
# 2024-05-21 00:21:03 :: create_folder :: INFO     -> Creating folder ./pdf
# 2024-05-21 00:21:05 :: create_folder :: INFO     -> Creating folder ./netcdf

# %% [markdown]
# Furthermore, the user can also combine time series and plot them against each other. The resulting "Gregory"-like plot allows the user to investigate the annual cycle as well as to detect model drift (if existing).

# %%
from global_time_series import GregoryPlot

# %% [markdown]
# Also in this case we have a simple class defined. The `GregoryPlot` class provides an easy interface to plot the Gregory-like plot for a given list of experiments.
#
# The comparison is done against ERA5 for the 2m temperature and CERES for the TOA net fluxes.
#
# By default both monthly and annual cycles are plotted, but the user can choose to plot only one of them by setting the `monthly` and `annual` parameters to `True` or `False`.

# %%
gp = GregoryPlot(models=['ICON','ICON'], exps=['historical-1990', 'ssp370'], sources=['lra-r100-monthly', 'lra-r100-monthly'],
            loglevel='INFO', monthly=False, annual=True)

# %%
gp.run()
# Out:
# 2024-05-21 00:21:31 :: Gregory plot :: INFO     -> Retrieving data for ICON historical-1990 lra-r100-monthly
# 2024-05-21 00:21:31 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:21:32 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-hist-lra
# 2024-05-21 00:21:32 :: Reader :: INFO     -> Fix names icon-destine-v1-hist-lra found in fixes files
# 2024-05-21 00:21:32 :: Reader :: INFO     -> Parent fix icon-destine-v1 found! Mergin with fixer_name fixes icon-destine-v1-hist-lra!
# 2024-05-21 00:21:32 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-21 00:21:32 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-05-21 00:22:13 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '1991-03-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '1991-03-01T00:00'}}
# 2024-05-21 00:22:13 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-05-21 00:22:13 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-05-21 00:22:13 :: Reader :: INFO     -> coordinates adjusted to ifs by AQUA fixer
# 2024-05-21 00:22:13 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:22:13 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:22:13 :: timmean_chunk_completeness :: INFO     -> 20 chunks from 1990-01-01 00:00:00 to 2009-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:22:13 :: timmean_chunk_completeness :: WARNING  -> Chunk 2009-01-31 00:00:00->2009-12-31 00:00:00 for has 9 elements instead of expected 12, timmean() will exclude this
# 2024-05-21 00:22:13 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:22:13 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:22:13 :: timmean_chunk_completeness :: INFO     -> 20 chunks from 1990-01-01 00:00:00 to 2009-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:22:13 :: timmean_chunk_completeness :: WARNING  -> Chunk 2009-01-31 00:00:00->2009-12-31 00:00:00 for has 9 elements instead of expected 12, timmean() will exclude this
# 2024-05-21 00:22:13 :: Gregory plot :: INFO     -> Retrieving data for ICON ssp370 lra-r100-monthly
# 2024-05-21 00:22:13 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:22:14 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-ssp370-lra
# 2024-05-21 00:22:14 :: Reader :: INFO     -> Fix names icon-destine-v1-ssp370-lra found in fixes files
# 2024-05-21 00:22:14 :: Reader :: INFO     -> Parent fix icon-destine-v1-ssp370 found! Mergin with fixer_name fixes icon-destine-v1-ssp370-lra!
# 2024-05-21 00:22:14 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-21 00:22:14 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-05-21 00:22:40 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '2020-09-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '2020-09-01T00:00'}}
# 2024-05-21 00:22:40 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-05-21 00:22:40 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-05-21 00:22:40 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-21 00:22:40 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:22:40 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:22:40 :: timmean_chunk_completeness :: INFO     -> 14 chunks from 2020-01-01 00:00:00 to 2033-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:22:40 :: timmean_chunk_completeness :: WARNING  -> Chunk 2033-01-31 00:00:00->2033-12-31 00:00:00 for has 5 elements instead of expected 12, timmean() will exclude this
# 2024-05-21 00:22:40 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:22:40 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:22:40 :: timmean_chunk_completeness :: INFO     -> 14 chunks from 2020-01-01 00:00:00 to 2033-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:22:40 :: timmean_chunk_completeness :: WARNING  -> Chunk 2033-01-31 00:00:00->2033-12-31 00:00:00 for has 5 elements instead of expected 12, timmean() will exclude this
# 2024-05-21 00:22:40 :: Gregory plot :: WARNING  -> No monthly data available. Monthly plot will not be drawn.
# 2024-05-21 00:22:40 :: Ref ts Gregory :: INFO     -> Reference data will be retrieved rom 1980-01-01 to 2010-12-31.
# 2024-05-21 00:22:40 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:22:41 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-05-21 00:22:41 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-05-21 00:22:41 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-05-21 00:22:41 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-05-21 00:22:42 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-05-21 00:22:42 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-05-21 00:22:42 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-05-21 00:22:42 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:22:42 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:22:42 :: timmean_chunk_completeness :: INFO     -> 31 chunks from 1980-01-01 00:00:00 to 2010-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:23:16 :: Ref toa Gregory :: INFO     -> Reference data will be retrieved rom 2001-01-01 to 2020-12-31.
# 2024-05-21 00:23:16 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-05-21 00:23:17 :: Reader :: INFO     -> Fix names in metadata is ceres-ebaf-destine-v1
# 2024-05-21 00:23:17 :: Reader :: INFO     -> Fix names ceres-ebaf-destine-v1 found in fixes files
# 2024-05-21 00:23:17 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-05-21 00:23:17 :: Reader :: INFO     -> Retrieving variables: ['mtnlwrf', 'mtnswrf']
# 2024-05-21 00:23:18 :: Reader :: INFO     -> Variables to be fixed: {'mtnlwrf': {'derived': '0.-toa_lw_all_mon', 'grib': True, 'attributes': {'valid_min': -500, 'valid_max': 0, 'positive': 'down'}}, 'mtnswrf': {'derived': 'solar_mon-toa_sw_all_mon', 'grib': True, 'attributes': {'valid_min': 0, 'valid_max': 1400, 'positive': 'down'}}}
# 2024-05-21 00:23:18 :: Reader :: INFO     -> mtnlwrf: converting units W m-2 --> W m**-2
# 2024-05-21 00:23:18 :: Reader :: INFO     -> mtnswrf: converting units W m-2 --> W m**-2
# 2024-05-21 00:23:18 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-05-21 00:23:18 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-05-21 00:23:18 :: timmean_chunk_completeness :: INFO     -> 20 chunks from 2001-01-01 00:00:00 to 2020-01-01 00:00:00 at YS frequency to be analysed...
# 2024-05-21 00:23:29 :: Gregory plot :: INFO     -> Saving figure to pdf
# 2024-05-21 00:23:29 :: create_folder :: INFO     -> Folder ./pdf already exists
# posx and posy should be finite values
# 2024-05-21 00:23:31 :: Gregory plot :: INFO     -> Saving data to netcdf
# 2024-05-21 00:23:31 :: create_folder :: INFO     -> Folder ./netcdf already exists
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
