# %% [markdown]
# # Global mean time series
#
# This notebook shows how to use the global_time_series diagnostic. Here we focus on the Timeseries and the Gregory Plot functionalities.

# %% [markdown]
# The `Timeseries` class provides an easy interface to plot gloabl time series for a given list of experiments and a variable or formula.

# %%
from aqua.diagnostics import Timeseries

# %% [markdown]
# Let's plot the global mean temperature for the historical experiment, with a comparison done with the same ERA5 time span and 1990-1999 climatology.

# %%
ts = Timeseries(var='mtnswrf', models='IFS-NEMO', exps='a1si', sources='monthly-r100s-atm2d',
                # startdate='1990-01-01', enddate='2019-12-01',
                #std_startdate='1990-01-01', std_enddate='1999-12-01', extend=False,
                #plot_ref=True,
                loglevel='INFO')

# %% [markdown]
# By default the `Timeseries` class will use `ERA5` as the reference dataset, but you can change it by setting the `plot_ref_kw` parameter to the desired dataset.
#
# The timeseries is generated, plot and saved by running the `run` method of the `Timeseries` class.
# By default monthly and annual mean are evaluated, but you can change it by setting the parameter to `monthly=False` or `annual=False`.
# The reference data can be plotted by setting the `plot_ref=True` parameter.

# %%
ts.run()
# Out:
# 2024-11-14 15:24:40 :: Timeseries :: INFO     -> Retrieving data for None IFS-NEMO a1si monthly-r100s-atm2d
# 2024-11-14 15:24:40 :: ConfigPath :: INFO     -> IFS-NEMO_a1si_monthly-r100s-atm2d triplet found in in mn5-phase2!
# 2024-11-14 15:24:40 :: Reader :: WARNING  -> realization parameter is required but is missing, setting to default 1
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Fix names in metadata is ifs-nemo-reduced-output-monthly-v2_0_1_9
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Fix names ifs-nemo-reduced-output-monthly-v2_0_1_9 found in fixes files
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Parent fix ifs-destine-v1 found! Mergin with fixer_name fixes ifs-nemo-reduced-output-monthly-v2_0_1_9!
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Retrieving variables: ['mtnswrf']
# 2024-11-14 15:24:41 :: Reader :: INFO     -> monthly deltat found, we will estimate a correction based on number of days per month
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True}}
# 2024-11-14 15:24:41 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-11-14 15:24:41 :: Reader :: INFO     -> coordinates adjusted to ifs by AQUA fixer
# 2024-11-14 15:24:41 :: Reader :: WARNING  -> Issue found in area, removing ['time'] coordinates
# 2024-11-14 15:24:41 :: Timeseries :: INFO     -> Monthly data retrieved
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Resampling to YS frequency and computing mean...
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-11-14 15:24:41 :: timmean_chunk_completeness :: INFO     -> 9 chunks from 1990-01-01 00:00:00 to 1998-01-01 00:00:00 at YS frequency to be analysed...
# 2024-11-14 15:24:41 :: Reader :: WARNING  -> Issue found in area, removing ['time'] coordinates
# 2024-11-14 15:24:41 :: Timeseries :: INFO     -> Annual data retrieved
# 2024-11-14 15:24:41 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-11-14 15:24:41 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-11-14 15:24:41 :: Timeseries :: WARNING  -> Reference data not found, skipping reference data
# 2024-11-14 15:24:41 :: Timeseries :: INFO     -> Plotting the timeseries
# 2024-11-14 15:24:45 :: Timeseries :: INFO     -> Saving figure to pdf
# 2024-11-14 15:24:45 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2024-11-14 15:24:45 :: create_folder :: INFO     -> Folder ./netcdf already exists

# %% [markdown]
# Furthermore, the user can also combine time series and plot them against each other. The resulting "Gregory"-like plot allows the user to investigate the annual cycle as well as to detect model drift (if existing).

# %%
from aqua_diagnostics.timeseries import GregoryPlot

# %% [markdown]
# Also in this case we have a simple class defined. The `GregoryPlot` class provides an easy interface to plot the Gregory-like plot for a given list of experiments.
#
# The comparison is done against ERA5 for the 2m temperature and CERES for the TOA net fluxes.
#
# By default both monthly and annual cycles are plotted, but the user can choose to plot only one of them by setting the `monthly` and `annual` parameters to `True` or `False`.

# %%
gp = GregoryPlot(models=['ICON','ICON'], exps=['historical-1990', 'ssp370'], sources=['lra-r100-monthly', 'lra-r100-monthly'],
            loglevel='INFO', monthly=False, annual=True)

# %%
gp.run()
# Out:
# 2024-08-14 15:32:43 :: Gregory plot :: INFO     -> Retrieving data for None ICON historical-1990 lra-r100-monthly
# 2024-08-14 15:32:43 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2024-08-14 15:32:44 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-hist-lra
# 2024-08-14 15:32:44 :: Reader :: INFO     -> Fix names icon-destine-v1-hist-lra found in fixes files
# 2024-08-14 15:32:44 :: Reader :: INFO     -> Parent fix icon-destine-v1 found! Mergin with fixer_name fixes icon-destine-v1-hist-lra!
# 2024-08-14 15:32:44 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-08-14 15:32:44 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-08-14 15:34:16 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '1991-03-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '1991-03-01T00:00'}}
# 2024-08-14 15:34:16 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-08-14 15:34:16 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-08-14 15:34:16 :: Reader :: INFO     -> coordinates adjusted to ifs by AQUA fixer
# 2024-08-14 15:34:16 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:34:16 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:34:16 :: timmean_chunk_completeness :: INFO     -> 27 chunks from 1990-01-01 00:00:00 to 2016-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:34:16 :: timmean_chunk_completeness :: WARNING  -> Chunk 2016-01-31 00:00:00->2016-12-31 00:00:00 for has 3 elements instead of expected 12, timmean() will exclude this
# 2024-08-14 15:34:16 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:34:16 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:34:16 :: timmean_chunk_completeness :: INFO     -> 27 chunks from 1990-01-01 00:00:00 to 2016-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:34:17 :: timmean_chunk_completeness :: WARNING  -> Chunk 2016-01-31 00:00:00->2016-12-31 00:00:00 for has 3 elements instead of expected 12, timmean() will exclude this
# 2024-08-14 15:34:17 :: Gregory plot :: INFO     -> Retrieving data for None ICON ssp370 lra-r100-monthly
# 2024-08-14 15:34:17 :: ConfigPath :: INFO     -> ICON_ssp370_lra-r100-monthly triplet found in in climatedt-phase1!
# 2024-08-14 15:34:17 :: Reader :: INFO     -> Fix names in metadata is icon-destine-v1-ssp370-lra
# 2024-08-14 15:34:17 :: Reader :: INFO     -> Fix names icon-destine-v1-ssp370-lra found in fixes files
# 2024-08-14 15:34:17 :: Reader :: INFO     -> Parent fix icon-destine-v1-ssp370 found! Mergin with fixer_name fixes icon-destine-v1-ssp370-lra!
# 2024-08-14 15:34:17 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-08-14 15:34:17 :: Reader :: INFO     -> Retrieving variables: ['2t', 'mtnlwrf', 'mtnswrf']
# 2024-08-14 15:36:01 :: Reader :: INFO     -> Variables to be fixed: {'mtnswrf': {'source': 'mtnswrf', 'grib': True, 'mindate': '2020-09-01T00:00'}, 'mtnlwrf': {'source': 'mtnlwrf', 'grib': True, 'mindate': '2020-09-01T00:00'}}
# 2024-08-14 15:36:01 :: Reader :: INFO     -> mtnswrf: converting units W m**-2 --> W m**-2
# 2024-08-14 15:36:01 :: Reader :: INFO     -> mtnlwrf: converting units W m**-2 --> W m**-2
# 2024-08-14 15:36:01 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-08-14 15:36:01 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:36:01 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:36:01 :: timmean_chunk_completeness :: INFO     -> 19 chunks from 2020-01-01 00:00:00 to 2038-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:36:02 :: timmean_chunk_completeness :: WARNING  -> Chunk 2038-01-31 00:00:00->2038-12-31 00:00:00 for has 11 elements instead of expected 12, timmean() will exclude this
# 2024-08-14 15:36:02 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:36:02 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:36:02 :: timmean_chunk_completeness :: INFO     -> 19 chunks from 2020-01-01 00:00:00 to 2038-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:36:02 :: timmean_chunk_completeness :: WARNING  -> Chunk 2038-01-31 00:00:00->2038-12-31 00:00:00 for has 11 elements instead of expected 12, timmean() will exclude this
# 2024-08-14 15:36:02 :: Gregory plot :: WARNING  -> No monthly data available. Monthly plot will not be drawn.
# 2024-08-14 15:36:02 :: Ref ts Gregory :: INFO     -> Reference data will be retrieved rom 1980-01-01 to 2010-12-31.
# 2024-08-14 15:36:02 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2024-08-14 15:36:02 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-08-14 15:36:02 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-08-14 15:36:02 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-08-14 15:36:03 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-08-14 15:36:03 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-08-14 15:36:03 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-08-14 15:36:03 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-08-14 15:36:03 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:36:03 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:36:03 :: timmean_chunk_completeness :: INFO     -> 31 chunks from 1980-01-01 00:00:00 to 2010-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:36:36 :: Ref toa Gregory :: INFO     -> Reference data will be retrieved rom 2001-01-01 to 2020-12-31.
# 2024-08-14 15:36:36 :: ConfigPath :: INFO     -> CERES_ebaf-toa42_monthly triplet found in in obs!
# 2024-08-14 15:36:36 :: Reader :: INFO     -> Fix names in metadata is ceres-ebaf-destine-v1
# 2024-08-14 15:36:36 :: Reader :: INFO     -> Fix names ceres-ebaf-destine-v1 found in fixes files
# 2024-08-14 15:36:36 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-08-14 15:36:36 :: Reader :: INFO     -> Retrieving variables: ['mtnlwrf', 'mtnswrf']
# 2024-08-14 15:36:37 :: Reader :: INFO     -> Variables to be fixed: {'mtnlwrf': {'derived': '0.-toa_lw_all_mon', 'grib': True, 'attributes': {'valid_min': -500, 'valid_max': 0, 'positive': 'down'}}, 'mtnswrf': {'derived': 'solar_mon-toa_sw_all_mon', 'grib': True, 'attributes': {'valid_min': 0, 'valid_max': 1400, 'positive': 'down'}}}
# 2024-08-14 15:36:37 :: Reader :: INFO     -> mtnlwrf: converting units W m-2 --> W m**-2
# 2024-08-14 15:36:37 :: Reader :: INFO     -> mtnswrf: converting units W m-2 --> W m**-2
# 2024-08-14 15:36:37 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:36:37 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:36:37 :: timmean_chunk_completeness :: INFO     -> 20 chunks from 2001-01-01 00:00:00 to 2020-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:36:57 :: Gregory plot :: INFO     -> Saving figure to pdf
# 2024-08-14 15:36:57 :: create_folder :: INFO     -> Folder ./pdf already exists
# posx and posy should be finite values
# 2024-08-14 15:36:59 :: Gregory plot :: INFO     -> Saving data to netcdf
# 2024-08-14 15:36:59 :: create_folder :: INFO     -> Folder ./netcdf already exists
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# For the `Timeseries` class it is possible to select an area over which to calculate the timeseries. This is done with the `lon_limits` and `lat_limits` parameters.

# %%
ts_area = Timeseries(var='2t', models='IFS-NEMO', exps='historical-1990', sources='lra-r100-monthly',
                     startdate='1990-01-01', enddate='1999-12-01',
                     std_startdate='1990-01-01', std_enddate='1999-12-01', extend=False,
                     lat_limits=[-90, 0],
                     loglevel='INFO')

# %%
ts_area.run()
# Out:
# 2024-08-14 15:52:54 :: Timeseries :: INFO     -> Retrieving data for None IFS-NEMO historical-1990 lra-r100-monthly
# 2024-08-14 15:52:54 :: ConfigPath :: INFO     -> IFS-NEMO_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2024-08-14 15:52:54 :: Reader :: INFO     -> No specific fix found, will call the default fix IFS-NEMO-default
# 2024-08-14 15:52:54 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-08-14 15:52:54 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly
# 2024-08-14 15:52:54 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-08-14 15:52:56 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-08-14 15:53:05 :: Timeseries :: INFO     -> Monthly data retrieved
# 2024-08-14 15:53:05 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:53:05 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:53:05 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:53:05 :: Timeseries :: INFO     -> Annual data retrieved
# 2024-08-14 15:53:05 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-08-14 15:53:06 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-08-14 15:53:06 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Resampling to YS frequency...
# 2024-08-14 15:53:06 :: Reader :: INFO     -> Checking if incomplete chunks has been produced...
# 2024-08-14 15:53:06 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2024-08-14 15:53:06 :: Timeseries :: INFO     -> Plotting the timeseries
# /LUMI_TYKKY_6gT15SL/miniconda/envs/env1/lib/python3.12/site-packages/xarray/core/indexing.py:1620: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# /LUMI_TYKKY_6gT15SL/miniconda/envs/env1/lib/python3.12/site-packages/xarray/core/indexing.py:1620: PerformanceWarning: Slicing with an out-of-order index is generating 10 times more chunks
#   return self.array[key]
# 2024-08-14 15:54:30 :: Timeseries :: INFO     -> Saving figure to pdf
# 2024-08-14 15:54:30 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2024-08-14 15:54:30 :: create_folder :: INFO     -> Folder ./netcdf already exists
