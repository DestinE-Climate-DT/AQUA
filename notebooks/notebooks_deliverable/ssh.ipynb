# %% [markdown]
# # Example notebook for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run. We first start by loading some of the modules, going up two levels so that we can import the `ssh` module

# %%
import sys
sys.path.insert(0, '/scratch/project_465000454/sughosh/AQUA/diagnostics')
from ssh import sshVariability

# %% [markdown]
# Please make sure that your config file is updated with the path to the output folder where the outputs of this notebook should be saved. In this code, if the output_directory key is not found in the config file, the output_directory variable will be set to a directory named 'output' in the current working directory (os.getcwd()).

# %% [markdown]
# The following cell executes the 'ssh_class.py' script with sshVariability class. The script performs the following:
#
# 1. Reads and parses the configuration file (`config.yml`) to retrieve the necessary parameters and settings for the script's execution. Please make sure that the config file is updated with the information you would like to analyze.
#
# 2. Within the `sshVariability` class, defines methods to retrieve, process, and analyze the SSH data for each model starting with AVISO observational data.
#
# 3. Saved the std computation under outputs along with visualization based on the target grid defined in the config file. AQUA regridder capability is used to regrid the data and visualize the results in subplots.
#
# 4. Difference plot between the model data and the AVISO data is plotted in subplots

# %%
# %%time
analyzer = sshVariability('/scratch/project_465000454/sughosh/AQUA/diagnostics/ssh/config.yaml')
analyzer.run()
# runtime is around 10-15 min depending on how much data you wish to analyse.
# Out:
# 2024-09-26 13:33:21 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:8787/status
# 2024-09-26 13:33:21 :: ssh_logger :: INFO     -> Workers=8, Memory=223.52 GiB
# 2024-09-26 13:33:21 :: Reader :: WARNING  -> The requested default fixer name AVISO-default does not exist in fixes files
# 2024-09-26 13:33:21 :: Reader :: WARNING  -> No fixes available for model AVISO, experiment ssh-L4, source daily
# 2024-09-26 13:33:24 :: ssh_logger :: INFO     -> aviso data already exists from 1993-01-01 to 2022-06-23
# 2024-09-26 13:33:26 :: ssh_logger :: INFO     -> Now loading data for other models to compare against AVISO ssh variability
# 2024-09-26 13:33:26 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'ICON', 'experiment': 'ssp370', 'source': 'daily-hpz10-oce2d', 'regrid': 'r010', 'variable': 'avg_zos', 'zoom': 10, 'timespan': ['2020-01-01', '2020-03-30']}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /scratch/project_465000454/sughosh/AQUA/diagnostics/ssh/ssh_class.py:494, in sshVariability.run(self, nworkers, args)
#     493 try:
# --> 494     reader = Reader(model=model_name['name'], exp=model_name['experiment'],
#     495                 source=model_name['source'], regrid=model_name['regrid'], zoom=model_name['zoom'], fix=True)
#     496 except:
#
# File /pfs/lustrep3/scratch/project_465000454/sughosh/AQUA/src/aqua/reader/reader.py:157, in Reader.__init__(self, model, exp, source, catalog, fix, regrid, regrid_method, areas, datamodel, streaming, stream_generator, startdate, enddate, rebuild, loglevel, nproc, aggregation, chunks, preproc, **kwargs)
#     156 # load the catalog
# --> 157 self.esmcat = self.cat(**intake_vars)[self.model][self.exp][self.source](**kwargs)
#     159 # manual safety check for netcdf sources (see #943)
#
# File /LUMI_TYKKY_WMqtmhL/miniconda/envs/env1/lib/python3.12/site-packages/intake/catalog/base.py:447, in Catalog.__getitem__(self, key)
#     445 if not isinstance(key, list) and key in self:
#     446     # triggers reload_on_change
# --> 447     s = self._get_entry(key)
#     448     if s.container == "catalog":
#
# File /LUMI_TYKKY_WMqtmhL/miniconda/envs/env1/lib/python3.12/site-packages/intake/catalog/utils.py:45, in reload_on_change.<locals>.wrapper(self, *args, **kwargs)
#      44 self.reload()
# ---> 45 return f(self, *args, **kwargs)
#
# File /LUMI_TYKKY_WMqtmhL/miniconda/envs/env1/lib/python3.12/site-packages/intake/catalog/base.py:333, in Catalog._get_entry(self, name)
#     332 entry._user_parameters = ups + (entry._user_parameters or [])
# --> 333 return entry()
#
# File /LUMI_TYKKY_WMqtmhL/miniconda/envs/env1/lib/python3.12/site-packages/intake/catalog/entry.py:79, in CatalogEntry.__call__(self, persist, **kwargs)
#      78 persist = persist or self._pmode
# ---> 79 s = self.get(**kwargs)
#      80 if persist != "never" and isinstance(s, PersistMixin) and s.has_been_persisted:
#
# File /LUMI_TYKKY_WMqtmhL/miniconda/envs/env1/lib/python3.12/site-packages/intake/catalog/local.py:273, in LocalCatalogEntry.get(self, **user_parameters)
#     272 plugin, open_args = self._create_open_args(user_parameters)
# --> 273 data_source = plugin(**open_args)
#     274 data_source.catalog_object = self._catalog
#
# File /pfs/lustrep3/scratch/project_465000454/sughosh/AQUA/src/aqua/gsv/intake_gsv.py:111, in GSVSource.__init__(self, request, data_start_date, data_end_date, bridge_end_date, timestyle, chunks, savefreq, timestep, timeshift, startdate, enddate, var, metadata, level, loglevel, **kwargs)
#     110         raise ValueError('Auto date selection not supported for timestyle=yearmonth. Please specify start and end date!')
# --> 111     data_start_date, data_end_date = self.parse_fdb(data_start_date, data_end_date)
#     113 if not startdate:
#
# File /pfs/lustrep3/scratch/project_465000454/sughosh/AQUA/src/aqua/gsv/intake_gsv.py:576, in GSVSource.parse_fdb(self, start_date, end_date)
#     574     yamlfile = self.fdbpath
# --> 576 with open(yamlfile, 'r') as file:
#     577     cfg = yaml.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/appl/local/climatedt/etc/fdb/config.yaml'
#
# During handling of the above exception, another exception occurred:
#
# NoDataError                               Traceback (most recent call last)
# File <timed exec>:2
#
# File /scratch/project_465000454/sughosh/AQUA/diagnostics/ssh/ssh_class.py:497, in sshVariability.run(self, nworkers, args)
#     494     reader = Reader(model=model_name['name'], exp=model_name['experiment'],
#     495                 source=model_name['source'], regrid=model_name['regrid'], zoom=model_name['zoom'], fix=True)
#     496 except:
# --> 497     raise NoDataError("Model data not found.")
#     499 model_data = reader.retrieve()
#     501 ssh_data = model_data[model_name['variable']]
#
# NoDataError: Model data not found.

# %% [markdown]
# Double-Checking the output files. The cells below are just checking if the output files contain the right data.

# %% [markdown]
# The subfolders "NetCDF" and "PDF" are automatically created under your defined "Output" folder. This is where individual outputs will get saved. Note: NetCDF files that get saved are ungridded as they get saved before AQUA regridder is used.

# %%
import xarray as xr

# %%
# Specify the path to the NetCDF file output
file_path = '../output/netcdf/AVISO_ssh-L4_daily_std.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 3kB -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 6kB -179.9 -179.6 -179.4 ... 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 8MB ...
