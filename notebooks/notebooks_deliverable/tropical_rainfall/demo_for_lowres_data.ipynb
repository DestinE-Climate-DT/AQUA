# %% [markdown]
# # Comparison of Low-Resolution Cicle3 arxiv

# %% [markdown]
# ### Content

# %% [markdown]
# 1. [The load of packages, modules, and data](#1-load-of-packages-modules-and-data)
#
# 2. [Comparison of Histograms](#2-comparison-of-histograms)
#
# 4. [Tropical Mean Comparison](#3-mean-comparison)
#
# 5. [The bias between models and observations](#4-calculation-of-a-bias-between-climatological-model-and-observations)
#
# [Go to the end of file](#the-end)

# %% [markdown]
# #

# %% [markdown]
# ## 1. The load of packages, modules, and data

# %%
from aqua import Reader
from tropical_rainfall import Tropical_Rainfall

# %% [markdown]
# ### Initialization of the tropical-rainfall diagnostic
#
# The class attributes by default are:
# - The latitude band of the tropical area: **trop_lat=15**
#
# - The number of bins in the histogram: **num_of_bins=5000**
#
# - The left edge of the first bin: **first_edge=0**
#
# - The width of each bin: **width_of_bin=0.5** mm/day

# %%
diag = Tropical_Rainfall(loglevel='warning')

# %% [markdown]
# ##### Loading the low-resolution arxiv

# %%
reader  = Reader(model="IFS-NEMO", exp="historical-1990", source="lra-r100-monthly") 
ifs_1990 = reader.retrieve(var=["mtpr"])
    
reader = Reader(model="IFS-NEMO", exp="ssp370", source="lra-r100-monthly")
ifs_ssp370 = reader.retrieve(var=["mtpr"])

reader  = Reader(model="ICON", exp="historical-1990", source="lra-r100-monthly") 
icon_1990 = reader.retrieve(var=["mtpr"])
    
reader = Reader(model="ICON", exp="ssp370", source="lra-r100-monthly")
icon_ssp370 = reader.retrieve(var=["mtpr"])
# Out:
# 2024-09-26 13:23:47 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-09-26 13:23:47 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly
# 2024-09-26 13:24:09 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-09-26 13:24:09 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment ssp370, source lra-r100-monthly
# 2024-09-26 13:25:19 :: Reader :: WARNING  -> You are asking for var ['mtpr'] but the fixes definition requires ['tprate'], which is not there.
# 2024-09-26 13:25:19 :: Reader :: WARNING  -> Retrieving ['mtpr'], but it would be safer to run with fix=False or to correct the fixes

# %% [markdown]
# The model data is at 100 km and monthly resolution, but let's ensure the observational data also has 100 km resolution.

# %%
reader = Reader(model="MSWEP", exp="past", source="monthly", regrid = "r100")
mswep = reader.retrieve(var=["mtpr"]) 
mswep = mswep.sel(time=slice('1990', '2020'))
mswep = reader.regrid(mswep)

reader = Reader(model="ERA5", exp="era5", source="monthly", regrid = "r100")
era5 = reader.retrieve(var=["mtpr"])
era5 = era5.sel(time=slice('1990', '2020'))
era5 = reader.regrid(era5)

# %%
lra_data = {
            'ifs_1990': {'data': ifs_1990, 'label': 'ifs_historical-1990'},
            'ifs_ssp370': {'data': ifs_ssp370, 'label': 'ifs_ssp370'},
            'icon_1990': {'data': icon_1990, 'label': 'icon_historical-1990'},
            'icon_ssp370': {'data': icon_ssp370, 'label': 'icon_ssp370'},
            'mswep': {'data': mswep, 'label': 'mswep_1990-2020'},
            'era5': {'data': era5, 'label': 'era5_1990-2020'},
            }

# %% [markdown]
# ## 2. Comparison of histograms

# %% [markdown]
# All output of the diagnostic is in the format of NetCDF or PDF. The paths to the repositories, where the diagnostic store the output, are

# %%
# Please change the path to the NetCDF files and the PDF files to your own path

diag.path_to_netcdf = "./netcdf/"
diag.path_to_pdf = "./pdf/"

# %% [markdown]
# The function `histogram` calculates and stores the histograms in a specified repository.

# %%
histograms = {}

for key, value in lra_data.items():
    histograms[key] = {}
    histograms[key]["data"] = diag.histogram(value["data"],  name_of_file=value["label"])
    histograms[key]["label"] = value["label"]
histograms = diag.tools.add_colors_to_dict(loaded_dict=histograms)
# Out:
# 2024-09-26 13:26:05 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_ifs_historical-1990_histogram_0-0_2500-0_5000_1990-01-01T00_2002-02-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:26:10 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_ifs_ssp370_histogram_0-0_2500-0_5000_2020-01-01T00_2039-12-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:26:16 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_icon_historical-1990_histogram_0-0_2500-0_5000_1990-01-01T00_2016-03-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:26:22 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_icon_ssp370_histogram_0-0_2500-0_5000_2020-01-01T00_2038-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:03 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_mswep_1990-2020_histogram_0-0_2500-0_5000_1990-01-01T00_2020-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:28 :: Trop. Rainfall :: WARNING  -> File ./netcdf/histograms/trop_rainfall_era5_1990-2020_histogram_0-0_2500-0_5000_1990-01-01T00_2020-12-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.

# %% [markdown]
# The diagnostic can provide us with a graphical comparison of the obtained histograms.

# %%
add = None
for key, value in histograms.items():
    add, path_to_pdf = diag.histogram_plot(value["data"],   add=add, figsize=1, pdf=True, save=False, smooth=True,
                xlogscale=False, ylogscale=True, color=value["color"], name_of_file= 'lra_comparison',
                loc='upper right', xmax=60,
                legend=value["label"])

# %% [markdown]
# ## 3. Mean comparison

# %% [markdown]
# The diagnostic can also give us a graphical comparison of the mean value along different coordinates.
#
# For example, the function `plot_of_average()` calculates the mean value of precipitation during
#  - December-January-February (`DJF`),
#  - March-April-May (`MAM`),
#  - June-July-August (`JJA`),
#  - September-October-November (`SON`), and
# - for the total period of time.
#
# Then the function  `average_into_netcdf(coord='lon')` calculates the mean value of precipitation along the longitude.
#
# In the end, the mean values of precipitation for each value of latitude in millimeters per day are:

# %%
seasonal_average_lat = {}
 
for key, value in lra_data.items():
    seasonal_average_lat[key] = {}
    seasonal_average_lat[key]["path"] = diag.average_into_netcdf(value["data"], path_to_netcdf=diag.path_to_netcdf+'mean/', 
                                                                 trop_lat=15, get_median=True,
                                                                 name_of_file=value["label"])
    seasonal_average_lat[key]["label"] = value["label"]
seasonal_average_lat = diag.tools.update_dict_of_loaded_analyses(loaded_dict=seasonal_average_lat)
# Out:
# 2024-09-26 13:27:39 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_ifs_historical-1990_along_lon_1990-01-01T00_2002-02-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:41 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_ifs_ssp370_along_lon_2020-09-01T00_2039-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:42 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_icon_historical-1990_along_lon_1990-09-01T00_2015-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:44 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_icon_ssp370_along_lon_2020-09-01T00_2038-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:45 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_mswep_1990-2020_along_lon_1990-09-01T00_2020-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:47 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_era5_1990-2020_along_lon_1990-09-01T00_2020-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.

# %%
fig, add = None, None
for key, value in seasonal_average_lat.items(): 
    add = diag.plot_of_average(path_to_netcdf=value["path"], trop_lat=90, ymax=13, fig=add, figsize=1.2,
                               color=value["color"], legend=value["label"],
                               loc='upper left', projection=False,
                               save=False, name_of_file= 'lra_comparison')

# %%
seasonal_average_lon = {}

for key, value in lra_data.items():
    seasonal_average_lon[key] = {}
    seasonal_average_lon[key]["path"] = diag.average_into_netcdf(value["data"], coord='lon', trop_lat=90, path_to_netcdf=diag.path_to_netcdf+'mean/', 
                                                                 name_of_file=value["label"])
    seasonal_average_lon[key]["label"] = value["label"]

seasonal_average_lon = diag.tools.update_dict_of_loaded_analyses(loaded_dict=seasonal_average_lon)
# Out:
# 2024-09-26 13:27:51 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_ifs_historical-1990_along_lat_1990-09-01T00_2001-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:52 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_ifs_ssp370_along_lat_2020-09-01T00_2039-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:54 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_icon_historical-1990_along_lat_1990-09-01T00_2015-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:55 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_icon_ssp370_along_lat_2020-09-01T00_2038-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:56 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_mswep_1990-2020_along_lat_1990-09-01T00_2020-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.
# 2024-09-26 13:27:58 :: Trop. Rainfall :: WARNING  -> File ./netcdf/mean/trop_rainfall_era5_1990-2020_along_lat_1990-09-01T00_2020-11-01T00_M.nc already exists. Set `rebuild=True` if you want to update it.

# %%
fig, add = None, None
for key, value in seasonal_average_lon.items():
    add = diag.plot_of_average(data=value["data"],   fig=add, figsize=0.8, ymax=14, save=False,
                color=value["color"], loc='upper left', name_of_file= 'lra_comparison',
                legend=value["label"])

# %% [markdown]
# ## 4. Calculation of a bias between climatological model and observations

# %% [markdown]
# Tropical-rainfall diagnostic provides the graphical representation of the bias between the mean value of precipitation of the climatological model and the mean value of observations.
#
# The mean value the function calculates for each season (`DJF`, `MAM`, `JJA`, `SON`) and for the total period of time.

# %%
diag.plot_bias(lra_data['ifs_1990']["data"], dataset_2 = lra_data['era5']["data"], seasons_bool=True, trop_lat=90,  
               vmin=-5, vmax=5, save=False,
               plot_title='The bias between IFS, historical 1990 and ERA5, monthly, 1 degree res (100km)', 
               name_of_file=lra_data['ifs_1990']["label"]+'_'+lra_data['era5']['label'])

# %% [markdown]
# #

# %% [markdown]
# ##### The end
